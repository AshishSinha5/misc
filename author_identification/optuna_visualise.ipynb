# %%
import optuna
import matplotlib.pyplot as plt
import pickle

# %%
f = open('optuna_logs/studies/study_LinearEmbbeddingModel_20210326-111010_0.8201328564128768.pickle', 'rb')

# %%
study = pickle.load(f)

# %%
optuna.visualization.matplotlib.plot_param_importances(study)
plt.savefig('images/EmbeddingBagFeatImp.png')
# Out:
# C:\Users\ashis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   """Entry point for launching an IPython kernel.

# %%
optuna.visualization.matplotlib.plot_optimization_history(study)
# Out:
# C:\Users\ashis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   """Entry point for launching an IPython kernel.

# %%
optuna.visualization.matplotlib.plot_edf([study])
# Out:
# C:\Users\ashis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ExperimentalWarning: plot_edf is experimental (supported from v2.2.0). The interface can change in the future.
#   """Entry point for launching an IPython kernel.

# %%
optuna.visualization.matplotlib.plot_contour(study, params=['optimizer', 'embed_dim'])
# Out:
# C:\Users\ashis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ExperimentalWarning: plot_contour is experimental (supported from v2.2.0). The interface can change in the future.
#   """Entry point for launching an IPython kernel.
# [W 2021-03-27 12:00:40,500] Output figures of this Matplotlib-based `plot_contour` function would be different from those of the Plotly-based `plot_contour`.

# %%
study.best_params
# Out:
# {'batch_size': 64,
#  'optimizer': 'RMSprop',
#  'lr': 0.036208458598920405,
#  'init_range': 0.46816558695052723,
#  'num_layers': 1,
#  'units_l0': 82,
#  'drop_l0': 0.4293082762379179,
#  'units_l1': 127,
#  'drop_l1': 0.6901682797978137,
#  'units_l2': 62,
#  'drop_l2': 0.1872497464773646,
#  'embed_dim': 59}
