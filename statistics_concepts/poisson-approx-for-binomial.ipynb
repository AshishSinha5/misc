# %%
import numpy as np
import random
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# Poisson distribution is a special case of binomial distribution if the number of trials is large, and the probability of success at any given trial is small.

# %%
n = 1000
p = 0.02
size = 10000
lmbda = n*p
binom = np.random.binomial(n = n, 
                           p = p,
                           size = size)
poisson = np.random.poisson(lam=lmbda, size=size)

# %%
plt.hist(binom, bins = 25, label = f'binom {n=}, {p=}')
plt.hist(poisson, bins = 25 , alpha = 0.5, label = f'poisson {lmbda=}')
plt.legend()
plt.show()

# %%
n_list = range(1, 3001, 100)
p_list = range(1, 91, 20)
size = 1000
print(f'{len(n_list) = }\n{len(p_list) = }')
# Out:
# len(n_list) = 30
# len(p_list) = 5

# %%
binom_dict = {}
poisson_dict = {}
for n in n_list:
    for p in p_list:
        p = p/100
        lmbda = n*p
        binom = np.random.binomial(n = n,
                                   p = p,
                                   size = size)
        poisson = np.random.poisson(lam=lmbda, size = size)

        binom_dict[(n,p)] = binom
        poisson_dict[lmbda] = poisson

# %%
for k1, k2 in (zip(binom_dict, poisson_dict)):
    n = k1[0]
    p = k1[1]
    lmbda = k2

    plt.hist(binom_dict[k1], bins = 25, label = f'binom {n=}, {p=}')
    plt.hist(poisson_dict[k2], alpha = 0.5, bins = 25, label = f'poisson {lmbda=}')
    plt.legend()
    plt.show()

# %%
binom_dict.keys()
# Out:
# dict_keys([(1, 0.01), (1, 0.21), (1, 0.41), (1, 0.61), (1, 0.81), (501, 0.01), (501, 0.21), (501, 0.41), (501, 0.61), (501, 0.81), (1001, 0.01), (1001, 0.21), (1001, 0.41), (1001, 0.61), (1001, 0.81), (1501, 0.01), (1501, 0.21), (1501, 0.41), (1501, 0.61), (1501, 0.81), (2001, 0.01), (2001, 0.21), (2001, 0.41), (2001, 0.61), (2001, 0.81), (2501, 0.01), (2501, 0.21), (2501, 0.41), (2501, 0.61), (2501, 0.81)])

# %%
# high n low p

plt.hist(binom_dict[(2501, 0.01)], bins = 25, label = f'binom')
plt.hist(poisson_dict[2501*0.01], alpha = 0.5, bins = 25, label = f'poisson')
plt.legend()
plt.show()

# %%
# high n high p
plt.hist(binom_dict[(2001, 0.81)], bins = 25, label = f'binom')
plt.hist(poisson_dict[2001*0.81], alpha = 0.5, bins = 25, label = f'poisson')
plt.legend()
plt.show()

# %%
# low n high p
plt.hist(binom_dict[(101, 0.81)], bins = 25, label = f'binom')
plt.hist(poisson_dict[101*0.81], alpha = 0.5, bins = 25, label = f'poisson ')
plt.legend()
plt.show()
